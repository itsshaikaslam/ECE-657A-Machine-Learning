# %%
# AUESTION 1 CODE SNIPPET

# %%
import seaborn as sbn

iris=sbn.load_dataset('iris')
print(type(iris))
print(iris.shape)
iris.head()
#iris

sbn.set(style='ticks')

#sbn.pairplot(iris)
sbn.set_palette("Set1", n_colors=3, desat=1)

sbn.set_palette("dark")


# %time sbn.pairplot(iris,hue='species',markers=['o','D','P'],size=4)

sbn.set_palette("Set1", n_colors=3, desat=1)

sbn.set_palette("dark")

#sbn.pairplot(iris,hue='species',vars=['sepal_length','sepal_width'])

#sbn.pairplot(iris,hue='species',x_vars=['sepal_length','sepal_width'],y_vars=['petal_length','petal_width'],markers=['o','D','P'],height=4)

#sbn.pairplot(iris,hue='species',x_vars=['petal_length','petal_width','sepal_width'],y_vars=['sepal_length'],markers=['o','D','P'],size=4)

#sbn.pairplot(iris,hue='species',x_vars=['petal_length','petal_width'],y_vars=['sepal_width'],markers=['o','D','P'],size=4)

# pair plot of petal_width vs petal_length

#sbn.pairplot(iris,hue='species',x_vars=['petal_width'],y_vars=['petal_length'],markers=['o','D','P'],size=4)

# pair plot of sepal_length vs petal_length

#sbn.pairplot(iris,hue='species',x_vars=['sepal_length'],y_vars=['petal_length'],markers=['o','D','P'],size=4)

# pair plot of sepal_width vs petal_length

#sbn.pairplot(iris,hue='species',x_vars=['sepal_width'],y_vars=['petal_length'],markers=['o','D','P'],size=4)

# pair plot of sepal_width vs petal_width

#sbn.pairplot(iris,hue='species',x_vars=['sepal_width'],y_vars=['petal_width'],markers=['o','D','P'],size=4)

# pair plot of sepal_length vs petal_width

#sbn.pairplot(iris,hue='species',x_vars=['sepal_length'],y_vars=['petal_width'],markers=['o','D','P'],size=4)

# pair plot of sepal_width vs sepal_length

#sbn.pairplot(iris,hue='species',x_vars=['sepal_width'],y_vars=['sepal_length'],markers=['o','D','P'],size=4)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <class 'pandas.core.frame.DataFrame'>
# (150, 5)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# CPU times: user 3.14 s, sys: 939 ms, total: 4.08 s
# Wall time: 3.01 s
